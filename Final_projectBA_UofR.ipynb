# %% [markdown]
# **The project is organized by contents. These contents can be found in the table of contents on the left**

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# !pip install statsmodels
import statsmodels.api as sm

# %% [markdown]
# Connect to the data file

# %%
df_main = pd.read_csv("https://raw.githubusercontent.com/David5761/Final_projectBA/main/student-por.csv")
df_main
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# General information about the data

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %% [markdown]
# General description of each column

# %%
df_main.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# Drop non-value columns

# %%
df_main.drop("school",axis=1,inplace=True)
df_main.drop("traveltime",axis=1,inplace=True)
df_main.drop("nursery",axis=1,inplace=True)
df_main.drop("reason",axis=1,inplace=True)
df_main.drop("guardian",axis=1,inplace=True)
df_main.drop("paid",axis=1,inplace=True)

df_main
# Out:
#     sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     F   18       U     GT3       A     4     4   at_home   teacher
# 1     F   17       U     GT3       T     1     1   at_home     other
# 2     F   15       U     LE3       T     1     1   at_home     other
# 3     F   15       U     GT3       T     4     2    health  services
# 4     F   16       U     GT3       T     3     3     other     other
# ..   ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644   F   19       R     GT3       T     2     3  services     other
# 645   F   18       U     LE3       T     3     1   teacher  services
# 646   F   18       U     GT3       T     1     1     other     other
# 647   M   17       U     LE3       T     3     1  services  services
# 648   M   18       R     LE3       T     3     2  services     other
#
#      studytime  ...  famrel freetime goout Dalc Walc health absences  G1  G2  \
# ...

# %% [markdown]
# Detailed content
#
# *   sex - student's sex (binary: 'F' - female or 'M' - male)
# *   age - student's age (numeric: from 15 to 22)
# *   address - student's home address type (binary: 'U' - urban or 'R' - rural)
# *   famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# *   Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# *   Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# *   Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
#
# *   Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
#
# *   Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
#
# *   studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
#
# *   failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# *  schoolsup - extra educational support (binary: yes or no)
# *   famsup - family educational support (binary: yes or no)
#
#
# *   activities - extra-curricular activities (binary: yes or no)
#
#
#
# *   higher - wants to take higher education (binary: yes or no)
#
# *   internet - Internet access at home (binary: yes or no)
# *   romantic - with a romantic relationship (binary: yes or no)
#
#
# *   famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
#
# *   freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# *   goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# *   Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
#
# *   Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
#
#
# *  health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# *   absences - number of school absences (numeric: from 0 to 93)
# *   G1 - first period grade (numeric: from 0 to 20)
#
#
# *   G2 - second period grade (numeric: from 0 to 20)
# *   G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# # Exploration of data

# %%
# Filter categorical variables
categorical_cols = [col for col in df_main.columns if not pd.api.types.is_numeric_dtype(df_main[col])]

# Create a figure
fig, axes = plt.subplots(4, 3, figsize=(12, 10))


counter = 0

# Iterate through categorical columns and subplots
for column in categorical_cols:
    ax = axes.flat[counter]
    df_main[column].value_counts().plot(kind="pie", ax=ax, autopct="%1.1f%%")  # Create pie chart in the subplot
    ax.set_title(f"Pie Chart for {column}")
    counter += 1


# Show the whole chart
plt.show()

# %%
filtered_data = df_main[df_main['Dalc'] == 5]


percentage_higher_edu = filtered_data['higher'].value_counts(normalize=True) * 100

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(percentage_higher_edu, labels=percentage_higher_edu.index, autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightgreen'],textprops={'fontsize': 20})
plt.title('Percentage of Students Pursuing Higher Education (Alcohol Daily Frequency = 5)',fontsize = 20)

# Show plot
plt.show()
percentage_higher_edu
# Out:
# higher
# yes    70.588235
# no     29.411765
# Name: proportion, dtype: float64

# %%
filtered_data = df_main[df_main['Dalc'] == 1]


percentage_higher_edu = filtered_data['higher'].value_counts(normalize=True) * 100

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(percentage_higher_edu, labels=percentage_higher_edu.index, autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightgreen'],textprops={'fontsize': 20})
plt.title('Percentage of Students Pursuing Higher Education (Alcohol Daily Frequency = 1)',fontsize = 20)

# Show plot
plt.show()
percentage_higher_edu
# Out:
# higher
# yes    91.796009
# no      8.203991
# Name: proportion, dtype: float64

# %% [markdown]
# Histograms

# %%
numeric_cols = [col for col in df_main.columns if pd.api.types.is_numeric_dtype(df_main[col])]

fig, axes = plt.subplots(4, 3, figsize=(15, 14))  # Adjust figsize for better visualization

counter = 0

for col in numeric_cols[:len(axes.flat)]:
    ax = axes.flat[counter]
    df_main[col].hist(ax=ax)
    ax.set_title(f"Histogram for {col}")
    counter += 1

plt.show()

# %%
# Group data by gender and calculate the sum of frequencies of alcohol consumption levels
grouped_data = df_main.groupby('sex')['Walc'].value_counts().unstack()


grouped_data.T.plot(kind='bar', stacked=True, color=['pink','skyblue'])



plt.title('Alcohol Consumption by Gender')
plt.xlabel('Alcohol Consumption Level (Walc)')
plt.ylabel('Count of Rows')
plt.xticks(rotation=0)
plt.legend(title='Gender')


plt.show()

# %% [markdown]
# Histogram of grades

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.histplot(df_main['G1'], bins=15,  kde=True,color='skyblue')
ax.set_xlabel("Grade")
ax.set_ylabel("Quantity of students")
plt.title('Histogram of first period grade');

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.histplot(df_main['G2'],bins=15,kde=True, color ='green')
ax.set_xlabel("Grade")
ax.set_ylabel("Quantity of students")
plt.title('Histogram of second period grade');

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.histplot(df_main['G3'], bins=15,  kde=True)
ax.set_xlabel("Grade")
ax.set_ylabel("Quantity of students")
plt.title('Histogram of final grade');

# %% [markdown]
# # Correlation

# %% [markdown]
# One-hot general

# %%
df_code_mode = df_main.copy()
df_code_mode = pd.get_dummies(data=df_code_mode)
df_code_mode
# Out:
#      age  Medu  Fedu  studytime  failures  famrel  freetime  goout  Dalc  \
# 0     18     4     4          2         0       4         3      4     1
# 1     17     1     1          2         0       5         3      3     1
# 2     15     1     1          2         0       4         3      2     2
# 3     15     4     2          3         0       3         2      2     1
# 4     16     3     3          2         0       4         3      2     1
# ..   ...   ...   ...        ...       ...     ...       ...    ...   ...
# 644   19     2     3          3         1       5         4      2     1
# 645   18     3     1          2         0       4         3      4     1
# 646   18     1     1          2         0       1         1      1     1
# 647   17     3     1          1         0       2         4      5     3
# 648   18     3     2          1         0       4         4      1     3
#
#      Walc  ...  famsup_no  famsup_yes  activities_no  activities_yes  \
# ...

# %%
correlation_matrix = df_code_mode.corr()

plt.figure(figsize=(25, 13))
mask = np.triu(np.ones_like(df_code_mode.corr()))
sns.heatmap(correlation_matrix,mask=mask, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
plt.title("Triangle correlation heatmap")
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

score_columns = ['Dalc', 'Walc']

for idx, score_column in enumerate(score_columns):
    corr = df_code_mode.corr()
    target_corr = corr[score_column].drop(score_column)

    target_corr_sorted = target_corr.sort_values(ascending=False)

    target_corr_sorted_df = target_corr_sorted.to_frame()

    sns.heatmap(target_corr_sorted_df, cmap="coolwarm", annot=True, fmt='.2f',
                cbar_kws={'orientation': 'vertical'}, ax=axs[idx])
    axs[idx].set_title(f'Correlation with {score_column}')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

score_columns = ['G1', 'G2','G3']

for idx, score_column in enumerate(score_columns):

    corr = df_code_mode.corr()
    target_corr = corr[score_column].drop(score_column)

    target_corr_sorted = target_corr.sort_values(ascending=False)

    target_corr_sorted_df = target_corr_sorted.to_frame()

    sns.heatmap(target_corr_sorted_df, cmap="coolwarm", annot=True, fmt='.2f',
                cbar_kws={'orientation': 'vertical'}, ax=axs[idx])
    axs[idx].set_title(f'Correlation with {score_column}')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

score_columns = ['famrel']

for idx, score_column in enumerate(score_columns):
    corr = df_code_mode.corr()
    target_corr = corr[score_column].drop(score_column)

    target_corr_sorted = target_corr.sort_values(ascending=False)

    target_corr_sorted_df = target_corr_sorted.to_frame()

    sns.heatmap(target_corr_sorted_df, cmap="coolwarm", annot=True, fmt='.2f',
                cbar_kws={'orientation': 'vertical'}, ax=axs[idx])
    axs[idx].set_title(f'Correlation with {score_column}')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

score_columns = ['studytime']

for idx, score_column in enumerate(score_columns):

    corr = df_code_mode.corr()
    target_corr = corr[score_column].drop(score_column)

    target_corr_sorted = target_corr.sort_values(ascending=False)

    target_corr_sorted_df = target_corr_sorted.to_frame()

    sns.heatmap(target_corr_sorted_df, cmap="coolwarm", annot=True, fmt='.2f',
                cbar_kws={'orientation': 'vertical'}, ax=axs[idx])
    axs[idx].set_title(f'Correlation with {score_column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistics

# %%
#Average of study time spent by students with moderate to high daily consumption of alcohol

result_1 =np.average(df_main[(df_main['Dalc'] == 5) | (df_main['Dalc'] == 4) | (df_main['Dalc'] == 3)]['studytime'])

result_1
# Out:
# 1.6623376623376624

# %%
#Average of study time spent by students with moderate to high weekly consumption of alcohol

result_2 =np.average(df_main[(df_main['Walc'] == 5) | (df_main['Walc'] == 4) | (df_main['Walc'] == 3)]['studytime'])

result_2
# Out:
# 1.7619047619047619

# %%
#Average of study time spent by students with zero to low to high daily consumption of alcohol

result_3 =np.average(df_main[(df_main['Dalc'] == 1) | (df_main['Dalc'] == 2)]['studytime'])

result_3
# Out:
# 1.9667832167832169

# %%
#Average of study time spent by students with zero to low weekly consumption of alcohol

result_3 =np.average(df_main[(df_main['Walc'] == 1) | (df_main['Walc'] == 2)]['studytime'])

result_3
# Out:
# 2.0377833753148615

# %%
#Average of grades by students with moderate to high daily consumption of alcohol

result_4_1 =np.average((df_main[(df_main['Dalc'] == 5) | (df_main['Dalc'] == 4) | (df_main['Dalc'] == 3)]['G1']))

result_4_2 =np.average((df_main[(df_main['Dalc'] == 5) | (df_main['Dalc'] == 4) | (df_main['Dalc'] == 3)]['G2']))

result_4_3 =np.average((df_main[(df_main['Dalc'] == 5) | (df_main['Dalc'] == 4) | (df_main['Dalc'] == 3)]['G3']))

result_4 = (result_4_1 + result_4_2 + result_4_3)/3
result_4
# Out:
# 10.298701298701298

# %%
#Average of grades by students with moderate to high daily consumption of alcohol

result_5_1 =np.average((df_main[(df_main['Dalc'] == 1) | (df_main['Dalc'] == 2)]['G1']))

result_5_2 =np.average((df_main[(df_main['Dalc'] == 1) | (df_main['Dalc'] == 2)]['G2']))

result_5_3 =np.average((df_main[(df_main['Dalc'] == 1) | (df_main['Dalc'] == 2)]['G3']))

result_5 = (result_5_1 + result_5_2 + result_5_3)/3
result_5
# Out:
# 11.803613053613054

# %%
#Average of grades by students with moderate to high weekly consumption of alcohol

result_6_1 =np.average((df_main[(df_main['Walc'] == 5) | (df_main['Walc'] == 4) | (df_main['Walc'] == 3)]['G1']))

result_6_2 =np.average((df_main[(df_main['Walc'] == 5) | (df_main['Walc'] == 4) | (df_main['Walc'] == 3)]['G2']))

result_6_3 =np.average((df_main[(df_main['Walc'] == 5) | (df_main['Walc'] == 4) | (df_main['Walc'] == 3)]['G3']))

result_6 = (result_6_1 + result_6_2 + result_6_3)/3
result_6
# Out:
# 11.068783068783068

# %%
#Average of grades by students with moderate to high weekly consumption of alcohol

result_7_1 =np.average((df_main[(df_main['Walc'] == 1) | (df_main['Walc'] == 2)]['G1']))

result_7_2 =np.average((df_main[(df_main['Walc'] == 1) | (df_main['Walc'] == 2)]['G2']))

result_7_3 =np.average((df_main[(df_main['Walc'] == 1) | (df_main['Walc'] == 2)]['G3']))

result_7 = (result_7_1 + result_7_2 + result_7_3)/3
result_7
# Out:
# 11.978169605373637

# %%
plt.scatter(df_main['G3'], df_main['Dalc'], color='blue', marker='o')


plt.title('Scatter plot of grades by alcohol consumption')
plt.xlabel('Grade')
plt.ylabel('Alcohol Consumption Level (Dalc)')


plt.show()

# %% [markdown]
# # Multiple linear regression

# %%
df_main['sex_dummi'] = df_main['sex'].replace({'F': 0, 'M': 1})


X = df_main[['sex_dummi','Dalc','goout']]
y = df_main['Walc']


model = LinearRegression()
model.fit(X, y)


coefficients = model.coef_


intercept = model.intercept_

print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [0.42349083 0.70585842 0.2781737 ]
# Intercept: 0.1604845012335283

# %%
X = df_main[['sex_dummi','goout','Dalc']]
y = df_main['Walc']


X = sm.add_constant(X)


model = sm.OLS(y, X).fit()

print(model.summary())
for attributeIndex in range (0, 4):
    print(model.pvalues[attributeIndex])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Walc   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     186.4
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           4.89e-87
# Time:                        16:10:47   Log-Likelihood:                -880.21
# No. Observations:                 649   AIC:                             1768.
# Df Residuals:                     645   BIC:                             1786.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1605      0.114      1.407      0.160      -0.063       0.384
# ...
